# %%
# !pip install pandas numpy==1.26.4 seaborn matplotlib scipy scikit-learn lmfit pysindy
# Out:
# ...
# WARNING: scikit-learn 1.2.2 does not provide the extra 'alldeps'
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# create directories for data and figures

from pathlib import Path

# create a path relative to the notebook's starting directory
data = Path("Data")
figures = Path("Figures")

# create directory if it doesn't exist 
data.mkdir(parents=True, exist_ok=True)
figures.mkdir(parents=True, exist_ok=True)

print(f"Directory created or already exists: {data.resolve()}")
print(f"Directory created or already exists: {figures.resolve()}")
# Out:
# Directory created or already exists: /Users/cdprin/Desktop/DynAffect-C/Data
# Directory created or already exists: /Users/cdprin/Desktop/DynAffect-C/Figures
